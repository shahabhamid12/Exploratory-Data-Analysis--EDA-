# %%
import pandas as pd
import numpy as np

# %%
tb = pd.read_csv('cdc_tuberculosis.csv')
tb
# Out:
#               Unnamed: 0 No. of TB cases Unnamed: 2 Unnamed: 3  TB incidence  \
# 0      U.S. jurisdiction            2019       2020       2021       2019.00
# 1                  Total           8,900      7,173      7,860          2.71
# 2                Alabama              87         72         92          1.77
# 3                 Alaska              58         58         58          7.91
# 4                Arizona             183        136        129          2.51
# 5               Arkansas              64         59         69          2.12
# 6             California           2,111      1,706      1,750          5.35
# 7               Colorado              66         52         58          1.15
# 8            Connecticut              67         54         54          1.88
# 9               Delaware              18         17         43          1.84
# 10  District of Columbia              24         19         19          3.39
# ...

# %%
tb = pd.read_csv('cdc_tuberculosis.csv',header=1)
tb
# Out:
#        U.S. jurisdiction   2019   2020   2021  2019.1  2020.1  2021.1
# 0                  Total  8,900  7,173  7,860    2.71    2.16    2.37
# 1                Alabama     87     72     92    1.77    1.43    1.83
# 2                 Alaska     58     58     58    7.91    7.92    7.92
# 3                Arizona    183    136    129    2.51    1.89    1.77
# 4               Arkansas     64     59     69    2.12    1.96    2.28
# 5             California  2,111  1,706  1,750    5.35    4.32    4.46
# 6               Colorado     66     52     58    1.15    0.90    1.00
# 7            Connecticut     67     54     54    1.88    1.50    1.50
# 8               Delaware     18     17     43    1.84    1.71    4.29
# 9   District of Columbia     24     19     19    3.39    2.75    2.84
# 10               Florida    558    412    499    2.60    1.91    2.29
# 11               Georgia    302    221    228    2.84    2.06    2.11
# ...

# %%
rename_dict = {'2019':'TB case 2019',
               '2020':'TB case 2020',
               '2021':'TB case 2021',
               '2019.1':'TB incidence 2019',
               '2020.1':'TB incidence 2020',
               '2021.1':'TB incidence 2021'            
}
tb = tb.rename(columns=rename_dict)
tb
# Out:
#        U.S. jurisdiction TB case 2019 TB case 2020 TB case 2021  \
# 0                  Total        8,900        7,173        7,860
# 1                Alabama           87           72           92
# 2                 Alaska           58           58           58
# 3                Arizona          183          136          129
# 4               Arkansas           64           59           69
# 5             California        2,111        1,706        1,750
# 6               Colorado           66           52           58
# 7            Connecticut           67           54           54
# 8               Delaware           18           17           43
# 9   District of Columbia           24           19           19
# 10               Florida          558          412          499
# 11               Georgia          302          221          228
# 12                Hawaii           99           92          106
# 13                 Idaho            7            8            4
# ...

# %%
tb.sum(axis=0)
# Out:
# U.S. jurisdiction    TotalAlabamaAlaskaArizonaArkansasCaliforniaCol...
# TB case 2019         8,9008758183642,111666718245583029973261085237...
# TB case 2020         7,1737258136591,706525417194122219282169239376...
# TB case 2021         7,8609258129691,750585443194992281064255127494...
# TB incidence 2019                                               109.94
# TB incidence 2020                                                93.09
# TB incidence 2021                                               102.94
# dtype: object

# %%
tb.dtypes
# Out:
# U.S. jurisdiction     object
# TB case 2019          object
# TB case 2020          object
# TB case 2021          object
# TB incidence 2019    float64
# TB incidence 2020    float64
# TB incidence 2021    float64
# dtype: object

# %%
tb =(pd.read_csv('cdc_tuberculosis.csv',header=1,thousands=',')
    .rename(columns=rename_dict)
)
tb
# Out:
#        U.S. jurisdiction  TB case 2019  TB case 2020  TB case 2021  \
# 0                  Total          8900          7173          7860
# 1                Alabama            87            72            92
# 2                 Alaska            58            58            58
# 3                Arizona           183           136           129
# 4               Arkansas            64            59            69
# 5             California          2111          1706          1750
# 6               Colorado            66            52            58
# 7            Connecticut            67            54            54
# 8               Delaware            18            17            43
# 9   District of Columbia            24            19            19
# 10               Florida           558           412           499
# 11               Georgia           302           221           228
# 12                Hawaii            99            92           106
# ...

# %%
tb.dtypes
# Out:
# U.S. jurisdiction     object
# TB case 2019           int64
# TB case 2020           int64
# TB case 2021           int64
# TB incidence 2019    float64
# TB incidence 2020    float64
# TB incidence 2021    float64
# dtype: object

# %%
tb.sum()
# Out:
# U.S. jurisdiction    TotalAlabamaAlaskaArizonaArkansasCaliforniaCol...
# TB case 2019                                                     17800
# TB case 2020                                                     14346
# TB case 2021                                                     15720
# TB incidence 2019                                               109.94
# TB incidence 2020                                                93.09
# TB incidence 2021                                               102.94
# dtype: object

# %%
nst2019 = pd.read_csv('nst-est2019-01.csv')
nst2019
# Out:
#    table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)  \
# 0   Table 1. Annual Estimates of the Resident Popu...
# 1                                     Geographic Area
# 2                                                 NaN
# 3                                       United States
# 4                                           Northeast
# ..                                                ...
# 61  Note: The estimates are based on the 2010 Cens...
# 62                                Suggested Citation:
# 63  Table 1. Annual Estimates of the Resident Popu...
# 64    Source: U.S. Census Bureau, Population Division
# 65                        Release Date: December 2019
#
#        Unnamed: 1      Unnamed: 2                          Unnamed: 3  \
# 0             NaN             NaN                                 NaN
# 1   April 1, 2010             NaN  Population Estimate (as of July 1)
# ...

# %%
nst2019 = pd.read_csv('nst-est2019-01.csv',header=3)
nst2019
# Out:
#                                            Unnamed: 0       Census  \
# 0                                       United States  308,745,538
# 1                                           Northeast   55,317,240
# 2                                             Midwest   66,927,001
# 3                                               South  114,555,744
# 4                                                West   71,945,553
# ..                                                ...          ...
# 58  Note: The estimates are based on the 2010 Cens...          NaN
# 59                                Suggested Citation:          NaN
# 60  Table 1. Annual Estimates of the Resident Popu...          NaN
# 61    Source: U.S. Census Bureau, Population Division          NaN
# 62                        Release Date: December 2019          NaN
#
#    Estimates Base         2010         2011         2012         2013  \
# 0     308,758,105  309,321,666  311,556,874  313,830,990  315,993,715
# ...

# %%
nst2019 = pd.read_csv('nst-est2019-01.csv',header=3,thousands=',').rename(columns={"Unnamed: 0": "Geographic Area"})
nst2019
# Out:
#                                       Geographic Area       Census  \
# 0                                       United States  308745538.0
# 1                                           Northeast   55317240.0
# 2                                             Midwest   66927001.0
# 3                                               South  114555744.0
# 4                                                West   71945553.0
# ..                                                ...          ...
# 58  Note: The estimates are based on the 2010 Cens...          NaN
# 59                                Suggested Citation:          NaN
# 60  Table 1. Annual Estimates of the Resident Popu...          NaN
# 61    Source: U.S. Census Bureau, Population Division          NaN
# 62                        Release Date: December 2019          NaN
#
#     Estimates Base         2010         2011         2012         2013  \
# 0      308758105.0  309321666.0  311556874.0  313830990.0  315993715.0
# ...

# %%
nst2019['Geographic Area']=nst2019['Geographic Area'].str.strip('.')

# %%
nst2020 = pd.read_csv('NST-EST2022-POP.csv')
nst2020
# Out:
#    table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)  \
# 0   Annual Estimates of the Resident Population fo...
# 1                                     Geographic Area
# 2                                                 NaN
# 3                                       United States
# 4                                           Northeast
# ..                                                ...
# 61  Note: The estimates are developed from a base ...
# 62                                Suggested Citation:
# 63  Annual Estimates of the Resident Population fo...
# 64    Source: U.S. Census Bureau, Population Division
# 65                        Release Date: December 2022
#
#                       Unnamed: 1                          Unnamed: 2  \
# 0                            NaN                                 NaN
# 1   April 1, 2020 Estimates Base  Population Estimate (as of July 1)
# ...

# %%
nst2020=pd.read_csv('nst-est2019-01.csv',header=3,thousands=',').rename(columns={"Unnamed: 0": "Geographic Area"})
nst2020
# Out:
#                                       Geographic Area       Census  \
# 0                                       United States  308745538.0
# 1                                           Northeast   55317240.0
# 2                                             Midwest   66927001.0
# 3                                               South  114555744.0
# 4                                                West   71945553.0
# ..                                                ...          ...
# 58  Note: The estimates are based on the 2010 Cens...          NaN
# 59                                Suggested Citation:          NaN
# 60  Table 1. Annual Estimates of the Resident Popu...          NaN
# 61    Source: U.S. Census Bureau, Population Division          NaN
# 62                        Release Date: December 2019          NaN
#
#     Estimates Base         2010         2011         2012         2013  \
# 0      308758105.0  309321666.0  311556874.0  313830990.0  315993715.0
# ...

# %%
nst2020['Geographic Area']=nst2020['Geographic Area'].str.strip('.')

# %%
td_marge = (
      tb.merge(right=nst2019,left_on='U.S. jurisdiction',right_on='Geographic Area')
    .merge(right=nst2020,left_on='U.S. jurisdiction',right_on='Geographic Area')
)
td_marge
# Out:
#        U.S. jurisdiction  TB case 2019  TB case 2020  TB case 2021  \
# 0                Alabama            87            72            92
# 1                 Alaska            58            58            58
# 2                Arizona           183           136           129
# 3               Arkansas            64            59            69
# 4             California          2111          1706          1750
# 5               Colorado            66            52            58
# 6            Connecticut            67            54            54
# 7               Delaware            18            17            43
# 8   District of Columbia            24            19            19
# 9                Florida           558           412           499
# 10               Georgia           302           221           228
# 11                Hawaii            99            92           106
# 12                 Idaho             7             8             4
# ...

# %%
td_marge["Recompute TB Incidence 2019"]= td_marge['TB case 2019']/td_marge['2019_y']*100000
td_marge
# Out:
#        U.S. jurisdiction  TB case 2019  TB case 2020  TB case 2021  \
# 0                Alabama            87            72            92
# 1                 Alaska            58            58            58
# 2                Arizona           183           136           129
# 3               Arkansas            64            59            69
# 4             California          2111          1706          1750
# 5               Colorado            66            52            58
# 6            Connecticut            67            54            54
# 7               Delaware            18            17            43
# 8   District of Columbia            24            19            19
# 9                Florida           558           412           499
# 10               Georgia           302           221           228
# 11                Hawaii            99            92           106
# 12                 Idaho             7             8             4
# ...
